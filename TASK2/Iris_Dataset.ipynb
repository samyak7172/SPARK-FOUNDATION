# %% [markdown]
# # The Spark Foundation
# ### Data Science and Business Analytics Intern.
#
#
# # Prediction using Unsupervised ML
#
# ## By:- Samyak Jain
#
# #### Problem Statement:- predict the optimum number of clusters and represent it visually.

# %%
## Importing libraires

import numpy as np     #for arays and maths manupulation
import pandas as pd    #for dataframes

#For graphs and visualization

import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns

# %%
#importing dataset

iris = pd.read_csv('Iris.csv')

# %% [markdown]
# ## Overview of Data

# %%
## looking data

iris.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
#shape of dataset columns and rows no.
print("No of columns: ",iris.shape[0])
print("No of columns: ",iris.shape[1])
#iris.shape
# Out:
# No of columns:  150
# No of columns:  6

# %%
#Now checking the cloumns in dataset
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#datatype and data info
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# - From this we get that there is one categorial variable and reamaing 5 are numerical

# %%
## Checking Null values

iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# - As we can see there is no null values present in data set.

# %%
# Getting numerical information about each numerical columns

iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Now in numerical column (Species) lets check how many categories are there

iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# - As we can saw that every species has equal length, no one dominating so we an say that dataset is balanced.

# %% [markdown]
# ## Visualizing Dataset

# %% [markdown]
# - In the visualizing case we will try to visualize every independet feature with the dependent feature (species).

# %% [markdown]
# ####  Independent Feature:- Id,  SepalLengthCm,  SepalWidthCm,  PetalLengthCm,  PetalWidthCm
#
# #### Dependent Feature : - Species

# %% [markdown]
# - For visualizing the dataset we will use matplotlib and seaborn library.
# - And using various charts like pairplot, scatter plot etc.,

# %% [markdown]
# - We will try to analyze the dataset in all three phases:-
#     - Univariate Analysis
#     - Bivariate Analysis
#     - Multivariate Analysis

# %% [markdown]
# ###  Univariate Analysis

# %%
## Here we stores the every species individually in different dataset

iris_setosa=iris.loc[iris['Species']=='Iris-setosa']
iris_virginica = iris.loc[iris['Species']=='Iris-virginica']
iris_versicolor = iris.loc[iris['Species']=='Iris-versicolor']

# %% [markdown]
# ##### Sepal Length

# %%
## Lest plot each according to sepal lenght

plt.figure(figsize=(8,2))
plt.plot(iris_setosa['SepalLengthCm'],np.zeros_like(iris_setosa['SepalLengthCm']),'o',label ='setosa')

plt.xlabel('SepallengthCm')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,2))
plt.plot(iris_versicolor['SepalLengthCm'],np.zeros_like(iris_versicolor['SepalLengthCm']),'^',label ='versicolor',color = 'green')

plt.xlabel('SepallengthCm')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,2))
plt.plot(iris_virginica['SepalLengthCm'],np.zeros_like(iris_virginica['SepalLengthCm']),'*',label ='virginica',color= 'Red')

plt.xlabel('SepallengthCm')
plt.legend()
plt.show()

# %% [markdown]
# - On the basis of Sepal Length we can clearly see that verginica species has highest sepal length, then versicolor and then setosa.
# - Setosa has least sepal width.

# %% [markdown]
# ##### Sepal Width

# %%
plt.figure(figsize=(8,4))
plt.plot(iris_setosa['SepalWidthCm'],np.zeros_like(iris_setosa['SepalWidthCm']),'o', label ='setosa')

plt.xlabel('Sepal Width(in cm)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(iris_virginica['SepalWidthCm'],np.zeros_like(iris_virginica['SepalWidthCm']),'*',label ='virginica',color='Red')
plt.xlabel('Sepal Width(in cm)')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(iris_versicolor['SepalWidthCm'],np.zeros_like(iris_versicolor['SepalWidthCm']),'^',label ='versicolor',color='green')
plt.xlabel('Sepal Width(in cm)')

plt.legend()
plt.show()

# %% [markdown]
# - On the basis of width you cant say anything except that satosa has highest width and almost all are getting concide.

# %% [markdown]
# ##### Petal Length

# %%
plt.figure(figsize=(8,4))
plt.plot(iris_setosa['PetalLengthCm'],np.zeros_like(iris_setosa['PetalLengthCm']),'^',label ='versicolor',color='green')
plt.xlabel('Petal Length(in cm)')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(iris_versicolor['PetalLengthCm'],np.zeros_like(iris_versicolor['PetalLengthCm']),'^',label ='versicolor',color='red')
plt.xlabel('Petal Length(in cm)')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(iris_virginica['PetalLengthCm'],np.zeros_like(iris_virginica['PetalLengthCm']),'^',label ='versicolor',color='green')
plt.xlabel('Petal Length(in cm)')

plt.legend()
plt.show()

# %%
iris.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
sns.barplot(x='Species', y="SepalLengthCm", data=iris)

# %%
sns.barplot(x='Species', y="SepalWidthCm", data=iris)

# %%
sns.barplot(x='Species', y="PetalLengthCm", data=iris)

# %%
sns.barplot(x='Species', y="PetalWidthCm", data=iris)

# %% [markdown]
# ### Bi-Variate  &  Multivariate Analysis

# %% [markdown]
# - In this we will analyse the two or more variable simultaneously

# %%
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='Species',height=7).map(plt.scatter,'SepalLengthCm','SepalWidthCm',s=100).add_legend()

# %%
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='Species',height=7).map(plt.scatter,'PetalLengthCm','PetalWidthCm',s=100).add_legend()

# %% [markdown]
# - From the above two plots we can clearly say that Iris-Setosa (Blue) is completetly seprated from the other two species (Irsi-versiciolor and Iris-Virginica).

# %% [markdown]
# - For this we are gonna use the paiplot to vizualize all features together

# %%
sns.pairplot(iris.drop(['Id'],axis=1,),hue="Species",size=4)
# Out:
# /usr/lib/python3/dist-packages/seaborn/axisgrid.py:2092: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - From these also we can say that setosa is completetly diffrent from the other two categories, but the verginica and vercicolor is overlapping each other in almost all cases.

# %% [markdown]
# ### Lets try to create model from these features

# %% [markdown]
# ## MODEL CREATION

# %%
from sklearn.model_selection import train_test_split  
train,test = train_test_split(iris,test_size=0.3, random_state=1)

# %%
train.shape
# Out:
# (105, 6)

# %%
test.shape
# Out:
# (45, 6)

# %%
train.drop(['Id'],axis=1)
test.drop(['Id'],axis=1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 14             5.8           4.0            1.2           0.2      Iris-setosa
# 98             5.1           2.5            3.0           1.1  Iris-versicolor
# 75             6.6           3.0            4.4           1.4  Iris-versicolor
# 16             5.4           3.9            1.3           0.4      Iris-setosa
# 131            7.9           3.8            6.4           2.0   Iris-virginica
# 56             6.3           3.3            4.7           1.6  Iris-versicolor
# 141            6.9           3.1            5.1           2.3   Iris-virginica
# 44             5.1           3.8            1.9           0.4      Iris-setosa
# 29             4.7           3.2            1.6           0.2      Iris-setosa
# 120            6.9           3.2            5.7           2.3   Iris-virginica
# 94             5.6           2.7            4.2           1.3  Iris-versicolor
# ...

# %%
X_train = train[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
Y_train = train.Species

X_test = test[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
Y_test = test.Species

# %%
# importing alll the necessary packages to use the various classification algorithms

from sklearn.linear_model import LogisticRegression  # for Logistic Regression algorithm
from sklearn.tree import DecisionTreeClassifier #for using Decision Tree Algoithm

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn import metrics

obj = LogisticRegression()
obj.fit(X_train,Y_train)
prediction=obj.predict(X_test)
print('The accuracy of the Logistic Regression is', metrics.accuracy_score(prediction,Y_test))
# Out:
# The accuracy of the Logistic Regression is 0.9777777777777777
# /usr/lib/python3/dist-packages/sklearn/linear_model/_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
obj2  = DecisionTreeClassifier()

obj.fit(X_train,Y_train)
prediction=obj.predict(X_test)
print('The accuracy of the Decision Tree is', metrics.accuracy_score(prediction,Y_test))
# Out:
# The accuracy of the Decision Tree is 0.9777777777777777
# /usr/lib/python3/dist-packages/sklearn/linear_model/_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# - Lets try for KNN

# %% [markdown]
# ###  KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

obj3 = KNeighborsClassifier(n_neighbors=5)
obj3.fit(X_train,Y_train)

prediction = obj.predict(X_test)
print("The accuracy of the KNN is", metrics.accuracy_score(prediction,Y_test))



#model=KNeighborsClassifier(n_neighbors=3) #this examines 3 neighbours for putting the new data into a class
#model.fit(X_train,Y_train)
#prediction=model.predict(X_test)
#print('The accuracy of the KNN is',metrics.accuracy_score(prediction,test_y))
# Out:
# The accuracy of the KNN is 0.9777777777777777
